# %%
import matplotlib.pyplot as plt
from _FigureJiazeHelper import *
from _BPRandomGraph import *


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Matplotlib settings

# plt.style.use('seaborn-whitegrid')
plt.rc('figure', figsize=(8, 5))
plt.rc('font', size=16)
plt.rc('font', family='sans-serif')
plt.rcParams['font.sans-serif'] = 'verdana'
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.edgecolor'] = basic_line_color
plt.rcParams['xtick.color'] = basic_line_color
plt.rcParams['ytick.color'] = basic_line_color
plt.rcParams['axes.labelsize'] = 'large'
plt.rcParams['lines.markersize'] = 12

# %config InlineBackend.figure_format = 'retina'

# %%
n, p = 100, 0.01
rg = RandomGraph(n, p)

fig = plt.figure(figsize=(15, 5))
widths = [5, 5, 5]
heights = [5]
spec5 = fig.add_gridspec(ncols=3, nrows=1, width_ratios=widths, height_ratios=heights)

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
rg.draw(ax=ax)

row = 0
col = 2
ax = fig.add_subplot(spec5[row, col])
rg_choosed = RandomGraph(n, 0.018)
rg_choosed.draw(ax=ax)

row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
rg = RandomGraph(n, 0.001)
rg.draw(ax=ax)
# Out:
# {0: array([-0.01107958,  0.911653  ]),
#  1: array([-0.28341393,  0.95163079]),
#  2: array([0.21837489, 0.02907248]),
#  3: array([ 0.65415916, -0.7937005 ]),
#  4: array([ 0.08022211, -0.90296525]),
#  5: array([0.74693349, 0.65366032]),
#  6: array([-0.99252049,  0.10663999]),
#  7: array([ 0.58673513, -0.74765112]),
#  8: array([-0.94631489, -0.28944531]),
#  9: array([-0.07376732,  0.96912794]),
#  10: array([-0.94812856, -0.43564356]),
#  11: array([ 0.19304072, -0.98022832]),
#  12: array([0.91288543, 0.38077167]),
#  13: array([ 0.6027713 , -0.52598021]),
#  14: array([0.88601337, 0.50043863]),
#  15: array([-0.80983345, -0.46002166]),
#  16: array([0.41086781, 0.93140006]),
#  17: array([0.11633201, 0.92083814]),
#  18: array([-0.49000533, -0.80904873]),
#  19: array([-0.64384993,  0.67524849]),
#  20: array([0.4716292, 0.7342951]),
#  21: array([ 0.45267755, -0.91268325]),
#  22: array([ 0.06847343, -0.12986471]),
#  23: array([-0.17467875,  0.98805217]),
# ...

# %%
psi_init = rg_choosed.bp_init()
psi = psi_init
for t in range(6):
    psi = rg_choosed.bp_iter(psi)
psi_i = rg_choosed.bp_marginal(psi)
i_color = ['#1f78b4' if psi_i[i]>0.5 else '#F45C0B' for i in range(rg_choosed.n) ]
rg_choosed.draw(node_color=i_color)
# Out:
# {0: array([-0.11837065, -0.30272205]),
#  1: array([ 0.28704187, -0.15061138]),
#  2: array([-0.45443605, -0.760531  ]),
#  3: array([-0.86079686,  0.06122696]),
#  4: array([-0.20713486,  0.55357295]),
#  5: array([-0.07382513,  0.98561103]),
#  6: array([ 0.16382986, -0.17724928]),
#  7: array([0.00420254, 0.49792645]),
#  8: array([0.18298205, 0.20102548]),
#  9: array([ 0.31730192, -0.21381653]),
#  10: array([0.89269018, 0.03102994]),
#  11: array([ 0.3432519 , -0.76377726]),
#  12: array([ 0.30425639, -0.7647178 ]),
#  13: array([-0.0423576 ,  0.34735433]),
#  14: array([0.1164939 , 0.91050176]),
#  15: array([ 0.40875144, -0.0838604 ]),
#  16: array([0.07020632, 0.42886717]),
#  17: array([-0.27586277,  0.27689197]),
#  18: array([-0.17025119, -0.55339282]),
#  19: array([-0.06468453,  0.4783984 ]),
#  20: array([-0.07543474,  0.53112362]),
#  21: array([0.03174564, 0.21022675]),
#  22: array([ 0.30751084, -0.04246221]),
#  23: array([0.05918878, 0.34127617]),
# ...
