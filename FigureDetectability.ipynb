# %%
import matplotlib.pyplot as plt
from EXPERIMENT_Detectability import *
# %load_ext autoreload
# %autoreload 2

# %%
load_path = f"./result/detectability/EXP25.10.19_detectability_BH.txt"
add_paths = f"./result/detectability/EXP25.10.20_detectability_BH_90more.txt"
snrs, Results = read_exp(load_path, add_paths=add_paths, num_result=2)
# Out:
# Additional result adding...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 load_path = f"./result/detectability/EXP25.10.19_detectability_BH.txt"
#       2 add_paths = f"./result/detectability/EXP25.10.20_detectability_BH_90more.txt"
# ----> 3 snrs, Results = read_exp(load_path, add_paths=add_paths, num_result=2)
#
# File D:\Work\PhD\_code\_nodeclassification\EXPERIMENT_Detectability.py:94, in read_exp(load_path, add_paths, num_result)
#      92     print("Additional result adding...")
#      93     for add_path in add_paths:
# ---> 94         with open(add_path, 'r') as add_f:
#      95             results_list = results_list + [row.strip().split() for row in add_f.readlines()]
#      96 results = np.round(np.float64(results_list), decimals=5)
#
# PermissionError: [Errno 13] Permission denied: '.'
