# %%
from _SBMMatrix import *
from oriNet import SyntheticSSBM
from _FigureJiazeHelper import *
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %load_ext autoreload
# %autoreload 2

# %%
# Matplotlib settings

# plt.style.use('seaborn-whitegrid')
plt.rc('figure', figsize=(8, 5))
plt.rc('font', size=16)
plt.rc('font', family='sans-serif')
plt.rcParams['font.sans-serif'] = 'verdana'
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.edgecolor'] = basic_line_color
plt.rcParams['xtick.color'] = basic_line_color
plt.rcParams['ytick.color'] = basic_line_color
plt.rcParams['axes.labelsize'] = 'large'
plt.rcParams['lines.markersize'] = 12

# %config InlineBackend.figure_format = 'retina'

# %%
# Any Shape
sizes = [10, 25, 20]
ps = [[0.9, 0.2, 0.1], [0.2, 0.8, 0.3], [0.1, 0.3, 0.9]]
sbm = SBMMatrix(sizes, ps)

# Symmetric Shape
# n = 3**4
# cin = n * 0.8
# cout = n * 0.2
# q = 1
# sbm = SymmetricSBM(n, cin, cout, q)
fig = plt.figure(figsize=(8, 8))
widths = [4]
heights = [4]
spec5 = fig.add_gridspec(ncols=1, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
c = gen_colors(start=colors_red[0], end=colors_blue[0], n=len(sbm.sizes))
plot_block_matrix(sbm.A, partition_names=list(range(len(sbm.sizes))), partition_counts=sbm.sizes, colors=c)

# %%
# Any Shape
sizes = [10, 10, 10]
ps = [[0.8, 0.2, 0.2], [0.2, 0.8, 0.2], [0.2, 0.2, 0.8]]
sbm = SBMMatrix(sizes, ps)
n = np.sum(sizes)
q = 3
pin = 0.8
pout = 0.2

# Symmetric Shape
# n = 3**4
# cin = n * 0.8
# cout = n * 0.2
# q = 1
# sbm = SymmetricSBM(n, cin, cout, q)
fig = plt.figure(figsize=(8, 8))
widths = [4]
heights = [4]
spec5 = fig.add_gridspec(ncols=1, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
c = gen_colors(start=colors_red[0], end=colors_blue[0], n=len(sbm.sizes))
plot_block_matrix(sbm.A, partition_names=list(range(len(sbm.sizes))), partition_counts=sbm.sizes, colors=c)

# %%
from numpy.linalg import eig
cin = n * pin
cout = n * pout
_lambda = (cin - cout) / (cin + (q-1) * cout)
eig_T = np.array([1] + [_lambda] * (q - 1))
sbm.change_operator('NB')
print(np.shape(sbm.A))
eig_B, _ = eig(sbm.A)
print("eig_T", eig_T)
# print(eig_B)
# Construct eigenvalues of transition matrix M
eig_M = []
for eT in eig_T:
    for eB in eig_B:
        eig_M.append(eT * eB)
# Out:
# (332, 332)
# eig_T [1.  0.5 0.5]

# %%
# Symmetric
n = 2**8
k = 2
c = 10
epsilon = 0.3
net = SyntheticSSBM(n, c, k, epsilon)

fig = plt.figure(figsize=(8, 8))
widths = [4]
heights = [4]
spec5 = fig.add_gridspec(ncols=1, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
c = gen_colors(start=colors_red[0], end=colors_blue[0], n=len(net.sbm.sizes))
plot_block_matrix(net.get_mat(), partition_names=list(range(len(net.sbm.sizes))), partition_counts=net.sbm.sizes, colors=c)
