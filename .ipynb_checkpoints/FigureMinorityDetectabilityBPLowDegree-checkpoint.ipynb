# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import contourpy
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as colors
from matplotlib.ticker import FormatStrFormatter
import numpy as np
from _FigureJiazeHelper import *
from _DetectabilityWithMeta import *
from _CommunityDetect import *
from EXPERIMENT_MINORITY import *
from scipy.optimize import linear_sum_assignment

# %load_ext autoreload
# %autoreload 2

# %%
# Matplotlib settings

# plt.style.use('seaborn-whitegrid')
plt.rc('figure', figsize=(8, 5))
plt.rc('font', size=10)
plt.rc('font', family='sans-serif')
plt.rcParams['font.sans-serif'] = 'verdana'
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.edgecolor'] = basic_line_color
plt.rcParams['xtick.color'] = basic_line_color
plt.rcParams['ytick.color'] = basic_line_color
plt.rcParams['axes.labelsize'] = 10  # 'large'
plt.rcParams['lines.markersize'] = 12
plt.rcParams['axes.linewidth'] = 0.5

# %matplotlib notebook
# %config InlineBackend.figure_format = 'retina'

# %%
# For big n
n = 6000
d = 15
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = False
fileID = 'amiExp24.3.28' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
# figsize (width, height) with inch, 1 inch = 72 pt
fig = plt.figure(figsize=(6.2, 3))
widths = [3, 3]
heights = [3]
spec5 = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["plasma"]
zcenter = 0.5
plot_subami = color_imshow_2d(plot_rhos, plot_zs, sub_ami, z_center=zcenter, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, ytickprecision=3)
# ax.set_xlabel(r'$\rho$', fontsize=20)
handels = []
handels += contour_data(plot_subami, ax, levels=[1e-3], fmt={1e-3: r'AMI$\simeq$0'}, color='gray', inline=False)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
handels += contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)

handels += contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)
handels += contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["cool"]
plot_subnumgroup = color_imshow_2d(plot_rhos, plot_zs, sub_num_group, z_center=2, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, vmax=4, ytickprecision=3)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)
contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)
contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)
lgd = fig.legend(handels, [r'AMI$\approx$0', r'$SNR=1$', r'$\frac{\lambda_3^2}{\lambda_1}=1$', r'$\frac{\lambda_4^2}{\lambda_1}=1$'], 
           loc=2, bbox_to_anchor=(0.94, 0.85),  fontsize=12, markerscale=2, frameon=False)
# plt.subplots_adjust(wspace=0.8)
# save_path = "./_Figure/Minority/" + "FigureMinorityAMISNR_" + f'Z_s{Z_s}Z_b{Z_b}' + ".pdf"
# # plt.tight_layout()
# plt.savefig(save_path, dpi=600, bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
show_num_group = np.flip(plot_subnumgroup, axis=0)
plt.matshow(show_num_group)
shape = np.shape(show_num_group)
for i in range(shape[0]):
        for j in range(shape[1]):
            c = show_num_group[i,j]
#             print(i, j, c)
            plt.text(j, i, str(c), va='center', ha='center', fontsize=5)

# %% [markdown]
# # BP

# %%
# For big n
n = 6000
d = 15
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
learnqby = 'FE'
fileID = 'amiExp24.3.30' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
# figsize (width, height) with inch, 1 inch = 72 pt
fig = plt.figure(figsize=(6.2, 3))
widths = [3, 3]
heights = [3]
spec5 = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["plasma"]
zcenter = 0.5
plot_subami = color_imshow_2d(plot_rhos, plot_zs, sub_ami, z_center=zcenter, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, ytickprecision=3)
ax.set_xlabel(r'$\rho$', fontsize=20)
handels = []
handels += contour_data(plot_subami, ax, levels=[1e-3], fmt={1e-3: r'AMI$\simeq$0'}, color='gray', inline=False)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
handels += contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)

handels += contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)
handels += contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["cool"]
plot_subnumgroup = color_imshow_2d(plot_rhos, plot_zs, sub_num_group, z_center=2, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, ytickprecision=3)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)
contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)
contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)
lgd = fig.legend(handels, [r'AMI$\approx$0', r'$SNR=1$', r'$\frac{\lambda_3^2}{\lambda_1}=1$', r'$\frac{\lambda_4^2}{\lambda_1}=1$'], 
           loc=2, bbox_to_anchor=(0.94, 0.85),  fontsize=12, markerscale=2, frameon=False)
# plt.subplots_adjust(wspace=0.8)
# save_path = "./_Figure/Minority/" + "FigureMinorityAMISNR_" + f'Z_s{Z_s}Z_b{Z_b}' + ".pdf"
# # plt.tight_layout()
# plt.savefig(save_path, dpi=600, bbox_extra_artists=(lgd,), bbox_inches='tight')

# %% [markdown]
# # BP 1 delta 0.04 20learn10exp

# %%
# For big n
n = 10000
d = 16
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
learnqby = 'FE'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 15
#      13 delta = 0.00173
#      14 results = []
# ---> 15 with open("n=10000d=16Zs=2Zb=2rho=0.5delta=0.00173_BPlearnq_FreeEnergy_83711SUB_inite0.402934.txt", 'r') as fr:
#      16     for line in fr.readlines():
#      17         line = line.strip().split(" ")
#
# File D:\BackProgram\Anaconda\envs\network\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# ...

# %%
# figsize (width, height) with inch, 1 inch = 72 pt
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_rhos, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\rho$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_rhos, sub_num_group)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\rho$")
plt.ylabel("#group")

row = 1
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_rhos, lambdas[:, 2]**2/lambdas[:, 0], label=r'$\frac{\lambda_3^2}{\lambda_1}=1$')
plt.plot(plot_rhos, lambdas[:, 3]**2/lambdas[:, 0], label=r'$\frac{\lambda_4^2}{\lambda_1}=1$')
plt.axhline(1, color='k', lw=1)
plt.xlabel(r"$\rho$")
plt.legend()

row = 1
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_rhos, lambdas[:, 2]**2/lambdas[:, 0], label=r'$\frac{\lambda_3^2}{\lambda_1}=1$')
plt.plot(plot_rhos, lambdas[:, 3]**2/lambdas[:, 0], label=r'$\frac{\lambda_4^2}{\lambda_1}=1$')
plt.axhline(1, color='k', lw=1)
plt.xlabel(r"$\rho$")
plt.legend()

# %%
print(np.min(sub_num_group))
# Out:
# 2.966666666666667

# %% [markdown]
# # BP rho=0.5 n=10000 d=16

# %%
# For big n
n = 10000
d = 16
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = True
writeCM = True
learnqby = 'FE'
fileID = 'amiExp24.4.21' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}_'\
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}'\
                              f'1exp20learn1rho_recordf'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.plot(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], '-r', label=r'$SNR$')
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00099: 2.0, 0.00118: 2.0, 0.00136: 3.0, 0.00154: 2.0, 0.00173: 4.0, 0.00191: 4.0, 0.0021: 5.0, 0.00228: 6.0, 0.00246: 4.0, 0.00265: 4.0, 0.00283: 4.0, 0.00302: 5.0, 0.0032: 5.0}

# %%
def observe_f(filepath, filename, rho):
    results = []
    with open(filepath, 'r') as fr:
        for line in fr.readlines():
            line = line.strip().split(" ")
            if line[0] == 'Finial':
                break
            result_line = []
            for datastr in line:
                # print(datastr)
                result_line.append(float(datastr.split("=")[1]))
            results.append(result_line)
    results = np.array(results)
    fig = plt.figure(figsize=(8, 6))
    widths = [4, 4]
    heights = [3, 3]
    spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
    row = 0
    col = 0
    ax = fig.add_subplot(spec5[row, col])
    plt.scatter(results[:, 0], results[:, 2], s=5)
    x = np.sort(np.unique(results[:, 0]))
    y = []
    for xi in x:
        y.append(np.min(results[np.argwhere(results[:, 0]==xi)[:, 0], :][:, 3]))
    print(f'q={x}, min_f={y},\ndiff_min_f={[np.around(y[i+1] - y[i], 5) for i in range(len(y)-1)]}')
    plt.plot(x, y, '-r', lw=1)
    plt.xlabel(r"$q$")
    plt.ylabel(r"Free Energy")
    # fileName = filepath.split('/')[4]
    plt.title(fileName.split(str(rho))[1].split('t=0')[0])
    
    cm_file = f'./result/confusionMatrix/{fileName.split("_BPlearnq_")[0]}.txt'
    print('Confusion Matrix of Final Partition:')
    with open(cm_file, 'r') as fr:
        for line in fr.readlines():
            line = line.strip().replace('[', '').replace(']', '')
            print(line)

# %%
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00099t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90848SUB_inite0.577375.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00118t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90849SUB_inite0.525151.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00136t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90850SUB_inite0.480916.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00154t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90851SUB_inite0.441016.txt"  # SNR<1
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00173t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90852SUB_inite0.402934.txt"  # SNR>1
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00191t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90853SUB_inite0.370157.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.0021t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90854SUB_inite0.338583.txt"  # q_minf=7, but result have 5 partition 
fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00228t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90855SUB_inite0.311178.txt"  # q_minf=6
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00246t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90849SUB_inite0.285922.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00265t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90848SUB_inite0.261324.txt" # q_minf=5 but result have 4 partition
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00283t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90850SUB_inite0.239758.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.00302t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90851SUB_inite0.218629.txt" # q_minf=6 but result have 5 partition
# fileName = "n=10000d=16Zs=2Zb=2rho=0.5delta=0.0032t=0__BP_FE_TrueEpsilon_moreq_BPlearnq_FreeEnergy_90855SUB_inite0.2.txt"  # q_minf=5
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-13.9247, -13.976, -14.0511, -14.1184, -14.1192, -14.1197, -14.1196],
# diff_min_f=[-0.0513, -0.0751, -0.0673, -0.0008, -0.0005, 0.0001]
# Confusion Matrix of Final Partition:
# 2.203e+03 1.080e+02 0.000e+00 1.200e+02 1.400e+01 6.300e+01
# 9.400e+01 2.192e+03 0.000e+00 1.060e+02 6.000e+00 1.030e+02
# 1.150e+02 1.130e+02 1.000e+00 2.135e+03 2.000e+01 7.400e+01
# 1.170e+02 1.230e+02 0.000e+00 1.130e+02 2.220e+02 1.956e+03

# %% [markdown]
# # BP rho=0.1 n=10000 d=16

# %%
# For big n
n = 10000
d = 16
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = True
writeCM = True
learnqby = 'FE'
fileID = 'amiExp24.4.24' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}_'\
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}'\
                              f'1exp20learn1rho0.1_moreq_recordf'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.plot(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], '-r', label=r'$SNR$')
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00026: 1.0, 0.00044: 1.0, 0.00063: 1.0, 0.00081: 1.0, 0.00099: 2.0, 0.00118: 4.0, 0.00136: 6.0, 0.00154: 4.0, 0.00173: 4.0, 0.00191: 4.0, 0.0021: 3.0, 0.00228: 4.0, 0.00246: 4.0, 0.00265: 7.0, 0.00283: 5.0, 0.00302: 7.0, 0.0032: 5.0}

# %%
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00026t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2051SUB_inite0.851717.txt"  # bad run
fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00044t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2331SUB_inite0.76339.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00063t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2332SUB_inite0.680479.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00081t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2333SUB_inite0.610183.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00099t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2334SUB_inite0.546724.txt"  # start SNR>1

# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00118t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2335SUB_inite0.486107.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00136t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2336SUB_inite0.433899.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00154t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2337SUB_inite0.386112.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00173t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2330SUB_inite0.339871.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00191t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2331SUB_inite0.299571.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.0021t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2332SUB_inite0.260303.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00228t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2333SUB_inite0.225859.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00246t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2334SUB_inite0.193813.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00265t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2335SUB_inite0.16232.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00283t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2332SUB_inite0.134477.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.00302t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2336SUB_inite0.106984.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.1delta=0.0032t=0__BP_FE_TrueEpsilon_rho0.1_moreq_BPlearnq_FreeEnergy_2333SUB_inite0.082569.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-14.2335, -14.3899, -14.416, -14.4162, -14.4162, -14.4165, -14.4175],
# diff_min_f=[-0.1564, -0.0261, -0.0002, 0.0, -0.0003, -0.001]
# Confusion Matrix of Final Partition:
#  167.   63.  133.  136.
#  142.   56.  143.  160.
#   44.   44. 4138.  239.
#   62.   29.  223. 4204.

# %% [markdown]
# # BP rho=0.32 n=10000 d=16

# %%
# For big n
n = 10000
d = 16
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = True
writeCM = True
additionId = "rho0.32_moreq"
learnqby = 'FE'
fileID = 'amiExp24.4.29' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}_'\
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}'\
                              f'1exp20learn1{additionId}_recordf'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5, label="#Com")
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.scatter(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], s=1, color='r', label=r'$SNR$')
plt.scatter(plot_zs, lambdas[:, 2]**2/lambdas[:, 0], s=1, color='g', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.scatter(plot_zs, lambdas[:, 3]**2/lambdas[:, 0], s=1, color='y', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.axhline(1, lw=1)
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00026: 1.0, 0.00044: 1.0, 0.00063: 1.0, 0.00081: 1.0, 0.00099: 2.0, 0.00118: 2.0, 0.00136: 3.0, 0.00154: 4.0, 0.00173: 3.0, 0.00191: 4.0, 0.0021: 4.0, 0.00228: 7.0, 0.00246: 7.0, 0.00265: 7.0, 0.00283: 5.0, 0.00302: 4.0, 0.0032: 4.0}

# %%
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00026t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2296SUB_inite0.85447.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00044t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2297SUB_inite0.770324.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00063t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2298SUB_inite0.692996.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00081t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2299SUB_inite0.628654.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00099t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2300SUB_inite0.571507.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00118t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2301SUB_inite0.517731.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00136t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2302SUB_inite0.472037.txt"  # start SNR>1
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00154t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2303SUB_inite0.430706.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00173t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2296SUB_inite0.391155.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00191t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2297SUB_inite0.357036.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.0021t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2298SUB_inite0.324098.txt" # start l3^2/l1>1
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00228t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2299SUB_inite0.295454.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00246t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2300SUB_inite0.269009.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00265t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2302SUB_inite0.243212.txt" # start l4^2/l1>1
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00283t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2301SUB_inite0.220559.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00302t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2297SUB_inite0.198333.txt"
# fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.0032t=0__BP_FE_TrueEpsilon_rho0.32_moreq_BPlearnq_FreeEnergy_2303SUB_inite0.178712.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-14.4459, -14.5344, -14.5834, -14.5835, -14.5835, -14.5835, -14.5834],
# diff_min_f=[-0.0885, -0.049, -0.0001, 0.0, 0.0, 0.0001]
# Confusion Matrix of Final Partition:
#  727.  399.  235.  238.
#  551.  471.  301.  228.
#   85.   84. 3186.  128.
#   73.  127.  136. 3100.

# %% [markdown]
# # BP rho=0.32 n=10000 d=16, FEcompareBy4SignificantFigure

# %%
# For big n
n = 10000
d = 16
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = True
writeCM = True
additionId = "rho0.32_moreq_4significantf"
learnqby = 'FE'
fileID = 'amiExp24.5.2' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}_'\
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}'\
                              f'1exp20learn1{additionId}_recordf'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5, label="#Com")
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.scatter(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], s=1, color='r', label=r'$SNR$')
plt.scatter(plot_zs, lambdas[:, 2]**2/lambdas[:, 0], s=1, color='g', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.scatter(plot_zs, lambdas[:, 3]**2/lambdas[:, 0], s=1, color='y', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.axhline(1, lw=1)
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00026: 1.0, 0.00044: 1.0, 0.00063: 1.0, 0.00081: 1.0, 0.00099: 1.0, 0.00118: 2.0, 0.00136: 1.0, 0.00154: 3.0, 0.00173: 3.0, 0.00191: 3.0, 0.0021: 3.0, 0.00228: 4.0, 0.00246: 4.0, 0.00265: 4.0, 0.00283: 4.0, 0.00302: 4.0, 0.0032: 4.0}

# %%
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00026t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7365SUB_inite0.85447.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00044t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7366SUB_inite0.770324.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00063t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7367SUB_inite0.692996.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00081t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7368SUB_inite0.628654.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00099t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7369SUB_inite0.571507.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00118t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7370SUB_inite0.517731.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00136t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7371SUB_inite0.472037.txt"  # start SNR>1
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00154t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7372SUB_inite0.430706.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00173t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7365SUB_inite0.391155.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00191t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7366SUB_inite0.357036.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.0021t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7367SUB_inite0.324098.txt" # start l3^2/l1>1
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00228t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7368SUB_inite0.295454.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00246t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7369SUB_inite0.269009.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00265t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7371SUB_inite0.243212.txt" # start l4^2/l1>1
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00283t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7370SUB_inite0.220559.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.00302t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7372SUB_inite0.198333.txt"
fileName = "n=10000d=16Zs=2Zb=2rho=0.32delta=0.0032t=0__BP_FE_TrueEpsilon_rho0.32_moreq_4significantf_BPlearnq_FreeEnergy_7366SUB_inite0.178712.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-13.9585, -14.8088, -15.377, -15.4768, -15.3307, -15.3378, -15.477],
# diff_min_f=[-0.8503, -0.5682, -0.0998, 0.1461, -0.0071, -0.1392]
# Confusion Matrix of Final Partition:
# 1.485e+03 4.700e+01 1.700e+01 1.400e+01
# 4.600e+01 1.469e+03 1.700e+01 1.700e+01
# 6.000e+00 1.000e+01 3.370e+03 5.000e+00
# 6.000e+00 1.000e+01 3.000e+00 3.365e+03

# %%
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00185t=0__BP_FE__BPlearnq_FreeEnergy_347067SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00198t=0__BP_FE__BPlearnq_FreeEnergy_347068SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00211t=0__BP_FE__BPlearnq_FreeEnergy_347069SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00225t=0__BP_FE__BPlearnq_FreeEnergy_347070SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00238t=0__BP_FE__BPlearnq_FreeEnergy_347071SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00251t=0__BP_FE__BPlearnq_FreeEnergy_347072SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00264t=0__BP_FE__BPlearnq_FreeEnergy_347073SUB_inite0.2.txt"
fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00278t=0__BP_FE__BPlearnq_FreeEnergy_347074SUB_inite0.2.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-1.51497, -1.63755, -1.73541, -1.81171, -1.85271, -1.85319, -1.85352],
# diff_min_f=[-0.12258, -0.09786, -0.0763, -0.041, -0.00048, -0.00033]
# Confusion Matrix of Final Partition:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 9
#       7 fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00264t=0__BP_FE__BPlearnq_FreeEnergy_347073SUB_inite0.2.txt"
#       8 fileName = "SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00278t=0__BP_FE__BPlearnq_FreeEnergy_347074SUB_inite0.2.txt"
# ----> 9 observe_f("./other/mode_net/record_f/" + fileName)
#
# Cell In[5], line 35, in observe_f(filepath)
#      33 cm_file = f'./result/confusionMatrix/{fileName.split("_BPlearnq_")[0]}.txt'
#      34 print('Confusion Matrix of Final Partition:')
# ---> 35 with open(cm_file, 'r') as fr:
# ...

# %% [markdown]
# # Same d BP Test (Compare 4 first significant figure of Free Energy)

# %%
# For big n
n = 6000
d = 5
Z_s = 2
Z_b = 3
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = False
writeCM = True
checkSNR = False
additionId = "24.6.1_SameD_2ndType_checkFE"
learnqby = 'FE'
fileID = 'amiExp24.5.31' + f'_n={n}_Zs={Z_s}_Zb={Z_b}_d={round(d)}_{"lambda" if Withlambda else ""}_' \
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_' \
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}_' \
                              f'{"CheckSNR" if checkSNR else ""}_' \
                              f'{additionId}'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5, label="#Com")
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.scatter(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], s=1, color='r', label=r'$SNR$')
plt.scatter(plot_zs, lambdas[:, 2]**2/lambdas[:, 0], s=1, color='g', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.scatter(plot_zs, lambdas[:, 3]**2/lambdas[:, 0], s=1, color='y', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.axhline(1, lw=1)
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00185: 4.0, 0.00198: 4.0, 0.00211: 5.0, 0.00225: 4.0, 0.00238: 5.0, 0.00251: 6.0, 0.00264: 5.0, 0.00278: 7.0}

# %%
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00185t=0__BP_FE__BPlearnq_FreeEnergy_349402SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00198t=0__BP_FE__BPlearnq_FreeEnergy_349403SUB_inite0.2.txt"
fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00211t=0__BP_FE__BPlearnq_FreeEnergy_349404SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00225t=0__BP_FE__BPlearnq_FreeEnergy_349405SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00238t=0__BP_FE__BPlearnq_FreeEnergy_349406SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00251t=0__BP_FE__BPlearnq_FreeEnergy_349407SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00264t=0__BP_FE__BPlearnq_FreeEnergy_349408SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_2ndType_checkFE_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00278t=0__BP_FE__BPlearnq_FreeEnergy_349409SUB_inite0.2.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-1.50979, -1.53101, -1.54841, -1.55403, -1.55457, -1.55404, -1.55403],
# diff_min_f=[-0.02122, -0.0174, -0.00562, -0.00054, 0.00053, 1e-05]
# Confusion Matrix of Final Partition:
# 288. 209. 126. 162. 198.
# 190. 295. 161. 182. 126.
# 169. 150. 949.  62.  50.
# 153. 110.  53. 989.  40.
# 148. 140.  37.  73. 939.

# %% [markdown]
# # Same d BP Test (Reserve 2 decimal of Free Energy)

# %%
# For big n
n = 6000
d = 5
Z_s = 2
Z_b = 3
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = False
writeCM = True
checkSNR = False
additionId = "24.6.1_SameD_checkFE_2dec"
learnqby = 'FE'
fileID = 'amiExp24.5.31' + f'_n={n}_Zs={Z_s}_Zb={Z_b}_d={round(d)}_{"lambda" if Withlambda else ""}_' \
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_' \
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}_' \
                              f'{"CheckSNR" if checkSNR else ""}_' \
                              f'{additionId}'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5, label="#Com")
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.scatter(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], s=1, color='r', label=r'$SNR$')
plt.scatter(plot_zs, lambdas[:, 2]**2/lambdas[:, 0], s=1, color='g', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.scatter(plot_zs, lambdas[:, 3]**2/lambdas[:, 0], s=1, color='y', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.axhline(1, lw=1)
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00185: 1.0, 0.00198: 1.0, 0.00211: 3.0, 0.00225: 4.0, 0.00238: 4.0, 0.00251: 5.0, 0.00264: 5.0, 0.00278: 5.0}

# %%
fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00185t=0__BP_FE__BPlearnq_FreeEnergy_351553SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00198t=0__BP_FE__BPlearnq_FreeEnergy_351554SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00211t=0__BP_FE__BPlearnq_FreeEnergy_351555SUB_inite0.2.txt"  # Good
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00225t=0__BP_FE__BPlearnq_FreeEnergy_351556SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00238t=0__BP_FE__BPlearnq_FreeEnergy_351557SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00251t=0__BP_FE__BPlearnq_FreeEnergy_351558SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00264t=0__BP_FE__BPlearnq_FreeEnergy_351559SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00278t=0__BP_FE__BPlearnq_FreeEnergy_351560SUB_inite0.2.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-1.4178, -1.42187, -1.42722, -1.4277, -1.42766, -1.42785, -1.4178],
# diff_min_f=[-0.00407, -0.00535, -0.00048, 4e-05, -0.00019, 0.01005]
# Confusion Matrix of Final Partition:
#  956.
# 1029.
# 1320.
# 1283.
# 1303.

# %% [markdown]
# # Same d BP Test (Reserve 3or2 decimal of Free Energy)

# %%
# For big n
n = 6000
d = 5
Z_s = 2
Z_b = 3
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
givenTrueEpsilon = False
writeCM = True
checkSNR = False
additionId = "24.6.1_SameD_checkFE_3or2dec"
learnqby = 'FE'
fileID = 'amiExp24.6.1' + f'_n={n}_Zs={Z_s}_Zb={Z_b}_d={round(d)}_{"lambda" if Withlambda else ""}_' \
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_' \
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}_' \
                              f'{"CheckSNR" if checkSNR else ""}_' \
                              f'{additionId}'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda)

# %%
fig = plt.figure(figsize=(8, 6))
widths = [4, 4]
heights = [3, 3]
spec5 = fig.add_gridspec(ncols=2, nrows=2, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
plt.plot(plot_zs, sub_ami)
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("AMI")

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
plt.scatter(plot_zs, sub_num_group, s=5, label="#Com")
# plt.axvline(1, color='k', lw=1)
plt.xlabel(r"$\delta$")
plt.ylabel("# of Community")
plt.scatter(plot_zs, lambdas[:, 1]**2/lambdas[:, 0], s=1, color='r', label=r'$SNR$')
plt.scatter(plot_zs, lambdas[:, 2]**2/lambdas[:, 0], s=1, color='g', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.scatter(plot_zs, lambdas[:, 3]**2/lambdas[:, 0], s=1, color='y', label=r'$\frac{\lambda_3^2}{\lambda_1}$')
plt.axhline(1, lw=1)
plt.legend()
print(dict(zip(plot_zs, sub_num_group)))
# print(sub_num_group)
# Out:
# {0.00185: 3.0, 0.00198: 3.0, 0.00211: 3.0, 0.00225: 4.0, 0.00238: 4.0, 0.00251: 5.0, 0.00264: 5.0, 0.00278: 5.0}

# %%
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00185t=0__BP_FE__BPlearnq_FreeEnergy_353687SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00198t=0__BP_FE__BPlearnq_FreeEnergy_353688SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00211t=0__BP_FE__BPlearnq_FreeEnergy_353689SUB_inite0.2.txt"  # Good
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00225t=0__BP_FE__BPlearnq_FreeEnergy_353690SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00238t=0__BP_FE__BPlearnq_FreeEnergy_353691SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00251t=0__BP_FE__BPlearnq_FreeEnergy_353692SUB_inite0.2.txt"
fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00264t=0__BP_FE__BPlearnq_FreeEnergy_353693SUB_inite0.2.txt"
# fileName = "24.6.1_SameD_checkFE_3or2dec_n=6000d=5Zs=2Zb=3rho=0.33delta=0.00278t=0__BP_FE__BPlearnq_FreeEnergy_353694SUB_inite0.2.txt"
observe_f("./other/mode_net/record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-1.48721, -1.57991, -1.6559, -1.6968, -1.71361, -1.71346, -1.71581],
# diff_min_f=[-0.0927, -0.07599, -0.0409, -0.01681, 0.00015, -0.00235]
# Confusion Matrix of Final Partition:
#  691.   29.  108.   92.   77.
#   45.  653.  102.   91.   93.
#   82.   53. 1158.   12.   12.
#   90.   60.   34. 1169.    6.
#   67.   55.   20.    8. 1170.

# %% [markdown]
# # BP Origin (Different d)

# %%
# For big n
n = 6000
d = 15
Z_s = 2
Z_b = 2
q = Z_s + Z_b
Withlambda = True
givenNumGroup = False
DC = False
BP = True
learnqby = 'FE'
givenTrueEpsilon = True
writeCM = False
stop_when_increasing_f = True
additionId = "rhoall_moreq_4sig_skipSNR_1"
fileID = 'amiExp24.5.17' + f'_n={n}_q={q}_d={round(d)}_{"lambda" if Withlambda else ""}_'\
                              f'{"givenNumGroup" if givenNumGroup else ""}_' \
                              f'{"DC" if DC else ""}_{"BP" if BP else ""}_learnqby{"MDL" if learnqby == "MDL" else "FE"}_'\
                              f'{"givenTrueEpsilon" if givenTrueEpsilon else ""}_{"writeCM" if writeCM else ""}'\
                              f'1exp20learn1{additionId}_recordf'
load_path = "./result/detectabilityWithMeta/" + fileID + ".txt"
plot_rhos, plot_zs, sub_ami, sub_num_group, lambdas = read_exp(load_path=load_path, Withlambda=Withlambda, exclude_rho=[0.1, 0.52, 0.56, 0.6, 0.64, 0.68])

# %%
# figsize (width, height) with inch, 1 inch = 72 pt
fig = plt.figure(figsize=(6.2, 3))
widths = [3, 3]
heights = [3]
spec5 = fig.add_gridspec(ncols=2, nrows=1, width_ratios=widths, height_ratios=heights)
row = 0
col = 0
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["plasma"]
zcenter = 0.5
plot_subami = color_imshow_2d(plot_rhos, plot_zs, sub_ami, z_center=zcenter, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, ytickprecision=3)
ax.set_xlabel(r'$\rho$', fontsize=20)
handels = []
handels += contour_data(plot_subami, ax, levels=[1e-3], fmt={1e-3: r'AMI$\simeq$0'}, color='gray', inline=False)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
handels += contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)

handels += contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)
handels += contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)

row = 0
col = 1
ax = fig.add_subplot(spec5[row, col])
cmap = mpl.colormaps["cool"]
plot_subnumgroup = color_imshow_2d(plot_rhos, plot_zs, sub_num_group, z_center=2, title="", xlabel=r'$\rho$', ylabel=r'$\delta$', cmap=cmap, ax=ax, fig=fig, ytickprecision=3)
plot_l4overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 3]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_l3overl1 = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**2/lambdas[:, 0], z_center=1, return_gridz=True)
plot_snrm = color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**2/lambdas[:, 0], z_center=1, return_gridz=True)
contour_data(plot_snrm, ax, levels=[1], fmt={1: r'$SNR=1$'}, color='red', inline=False)
contour_data(plot_l4overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_4^2}{\lambda_1}=1$'}, color='green', inline=False)
contour_data(plot_l3overl1, ax, levels=[1], fmt={1: r'$\frac{\lambda_3^2}{\lambda_1}=1$'}, color='black', inline=False)

contour_data(color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**(3/2)*abs(lambdas[:, 2])**(1/2)/lambdas[:, 0], z_center=1, return_gridz=True),
             ax, levels=[1], fmt={1: r'$Test=1$'}, color='yellow', inline=False)
contour_data(color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**(3/2)*abs(lambdas[:, 3])**(1/2)/lambdas[:, 0], z_center=1, return_gridz=True),
             ax, levels=[1], fmt={1: r'$Test=1$'}, color='yellow', inline=False)

lgd = fig.legend(handels, [r'AMI$\approx$0', r'$SNR=1$', r'$\frac{\lambda_3^2}{\lambda_1}=1$', r'$\frac{\lambda_4^2}{\lambda_1}=1$'], 
           loc=2, bbox_to_anchor=(0.94, 0.85),  fontsize=12, markerscale=2, frameon=False)
# plt.subplots_adjust(wspace=0.8)
# save_path = "./_Figure/Minority/" + "FigureMinorityAMISNR_" + f'Z_s{Z_s}Z_b{Z_b}' + ".pdf"
# # plt.tight_layout()
# plt.savefig(save_path, dpi=600, bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# C:\Users\24391\AppData\Local\Temp\ipykernel_1412\2616541606.py:35: RuntimeWarning: invalid value encountered in power
#   contour_data(color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 1]**(3/2)*abs(lambdas[:, 2])**(1/2)/lambdas[:, 0], z_center=1, return_gridz=True),
# C:\Users\24391\AppData\Local\Temp\ipykernel_1412\2616541606.py:37: RuntimeWarning: invalid value encountered in power
#   contour_data(color_imshow_2d(plot_rhos, plot_zs, lambdas[:, 2]**(3/2)*abs(lambdas[:, 3])**(1/2)/lambdas[:, 0], z_center=1, return_gridz=True),

# %%
show_num_group = np.flip(plot_subnumgroup, axis=0)
plt.matshow(show_num_group)
shape = np.shape(show_num_group)
for i in range(shape[0]):
        for j in range(shape[1]):
            c = show_num_group[i,j]
#             print(i, j, c)
            plt.text(j, i, str(c), va='center', ha='center', fontsize=5)

# %% [markdown]
# # BP init with BH

# %%
fileName = "2ndType_BPlearnq_n=6000d=5Zs=2Zb=3rho=0.12delta=0.00161t=0_BPlearnq_FreeEnergy_991137SUB_inite0.2.txt"
observe_f("./result/test_record_f/" + fileName)
# Out:
# q=[1. 2. 3. 4. 5. 6. 7.], min_f=[-1.54165, -1.55761, -1.56924, -1.57104, -1.57257, -1.5731, -1.57279],
# diff_min_f=[-0.01596, -0.01163, -0.0018, -0.00153, -0.00053, 0.00031]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 fileName = "2ndType_BPlearnq_n=6000d=5Zs=2Zb=3rho=0.12delta=0.00161t=0_BPlearnq_FreeEnergy_991137SUB_inite0.2.txt"
# ----> 2 observe_f("./result/test_record_f/" + fileName)
#
# Cell In[1], line 30, in observe_f(filepath)
#      28 plt.xlabel(r"$q$")
#      29 plt.ylabel(r"Free Energy")
# ---> 30 fileName = filepath.split('/')[4]
#      31 plt.title(fileName.split("0.33")[1].split('t=0')[0])
#      33 cm_file = f'./result/confusionMatrix/{fileName.split("_BPlearnq_")[0]}.txt'
#
# IndexError: list index out of range
